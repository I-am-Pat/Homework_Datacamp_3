# %% [markdown]
# ## Quiz2.สร้างกราฟฟังก์ชั่น Sin (เหมือนตัวอย่าง) พร้อมใส่ชื่อกราฟ รายละเอียดแต่ละแกน เปลี่ยนสีเส้นเป็นสีชมพู

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,30)
y = np.sin(x)
plt.plot(x , y , c = 'm')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Y = Sin(X)')
# Out:
# Text(0.5, 1.0, 'Y = Sin(X)')
